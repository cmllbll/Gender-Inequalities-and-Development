# %%
# Projet Python 
# Objectif: nettoyer la base de données de l'OCDE pour la rendre compréhensible
# Données 2019

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import urllib
import bs4
import pandas
from urllib import request
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model

# %% [markdown]
# # Création de la base de données

# %% [markdown]
# ## Traitement des données de l'OCDE
# Objectif: Importer, traiter et sélectionner les données de l'OCDE.
# On se concentre ici sur les données "pratiques" reflétant la réalité de la situation dans les pays étudiés.

# %%
df2 = pd.read_csv('C:/Users/julie/Documents/ENSAE/2A/S1/python/projet/oecd3.csv', sep=',', encoding='latin-1')
#les données sont récupérées en téléchargeant les données via un fichier csv recueilli sur la page: https://stats.oecd.org/viewhtml.aspx?datasetcode=GIDDB2019&lang=fr

# %%
# autre méthode 
# df2=pd.read_csv('./oecd3.csv', sep=',', encoding='latin-1')

# %%
df2.head(5)
# Out:
#   ï»¿"REGION" RÃ©gion LOCATION       Pays  INC   Revenu          VAR  \
# 0         ASI    Asie      AUS  Australie  HIN  ÃlevÃ©    DF_HR_LAW
# 1         ASI    Asie      AUS  Australie  HIN  ÃlevÃ©    DF_HR_ATT
# 2         ASI    Asie      AUS  Australie  HIN  ÃlevÃ©  DF_HR_PRACT
# 3         ASI    Asie      AUS  Australie  HIN  ÃlevÃ©    DF_DV_LAW
# 4         ASI    Asie      AUS  Australie  HIN  ÃlevÃ©    DF_IN_LAW
#
#     Variable  TIME  AnnÃ©e  Value  Flag Codes  Flags
# 0        Loi  2019    2019   0.50         NaN    NaN
# 1  Attitudes  2019    2019  21.10         NaN    NaN
# 2   Pratique  2019    2019   1.82         NaN    NaN
# 3        Loi  2019    2019   0.00         NaN    NaN
# 4        Loi  2019    2019   0.00         NaN    NaN

# %%
# on ne sélectionne que les lignes 'pratique' qui correspondent à la réalité des faits 
df_pratique=df2[df2['Variable']=="Pratique"]

# %%
#on cherche à renommer les colonnes
df_pratique.columns
df_pratique.rename(columns={'ï»¿"REGION"': 'region_monde', 'RÃ©gion': 'region', 'LOCATION': 'Country Code'}, inplace=True)
# Out:
# C:\Users\julie\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_pratique2=df_pratique[df_pratique['region_monde']=="ALL"]

# %%
df_pratique2.head(5)
# Out:
#    region_monde               region Country Code       Pays  INC   Revenu  \
# 29          ALL  Toutes les rÃ©gions          AUS  Australie  HIN  ÃlevÃ©
# 34          ALL  Toutes les rÃ©gions          AUS  Australie  HIN  ÃlevÃ©
# 36          ALL  Toutes les rÃ©gions          AUS  Australie  HIN  ÃlevÃ©
# 38          ALL  Toutes les rÃ©gions          AUS  Australie  HIN  ÃlevÃ©
# 42          ALL  Toutes les rÃ©gions          AUS  Australie  HIN  ÃlevÃ©
#
#                  VAR  Variable  TIME  AnnÃ©e   Value  Flag Codes  Flags
# 29       DF_HR_PRACT  Pratique  2019    2019    1.82         NaN    NaN
# 34     RPI_VAW_PRACT  Pratique  2019    2019   16.90         NaN    NaN
# 36      RPI_MW_PRACT  Pratique  2019    2019  105.50         NaN    NaN
# 38      RPI_RA_PRACT  Pratique  2019    2019   11.00         NaN    NaN
# 42  RAPFR_SAFS_PRACT  Pratique  2019    2019   50.00         NaN    NaN

# %%
df_pratique_final=df_pratique2[['Country Code', 'Pays', 'Revenu', 'VAR', 'Value']]

# %%
df_pratique_final.head(5)
# Out:
#    Country Code       Pays   Revenu               VAR   Value
# 29          AUS  Australie  ÃlevÃ©       DF_HR_PRACT    1.82
# 34          AUS  Australie  ÃlevÃ©     RPI_VAW_PRACT   16.90
# 36          AUS  Australie  ÃlevÃ©      RPI_MW_PRACT  105.50
# 38          AUS  Australie  ÃlevÃ©      RPI_RA_PRACT   11.00
# 42          AUS  Australie  ÃlevÃ©  RAPFR_SAFS_PRACT   50.00

# %%
df_pratique_final.shape
# Out:
# (3426, 5)

# %% [markdown]
# ## Traitement des données de la BM
# Objectif: Obtenir pour chaque pays de la base de données le PIB par tête en 2019

# %%
# On veut faire un left join avec la bdd de la BM pour avoir la variable gdp qui nous intéresse
df = pd.read_csv('C:/Users/julie/Documents/ENSAE/2A/S1/python/projet/wdi2.csv', sep=';')

# %%
df.head(5)
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code 1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS  NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS  NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS  NaN
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS  NaN
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS  NaN
#
#   1961 1962 1963 1964 1965  ...         2011         2012         2013  \
# 0  NaN  NaN  NaN  NaN  NaN  ...  15,98125613  16,32047487  16,64324286
# 1  NaN  NaN  NaN  NaN  NaN  ...  28,38183599  32,22402744   32,0464781
# 2  NaN  NaN  NaN  NaN  NaN  ...  15,29595036  20,52535278  19,46138334
# 3  NaN  NaN  NaN  NaN  NaN  ...  65,47061541   66,3035992  66,49601015
# 4  NaN  NaN  NaN  NaN  NaN  ...          NaN          NaN          NaN
#
#           2014         2015         2016         2017         2018  \
# 0  16,99469495  17,31316828  17,60495006          NaN          NaN
# 1   31,3235788  33,31216313  38,38043319  39,75420135  42,16824107
# 2  17,79069847  16,55347014  23,90789663  24,62472499  26,81389966
# 3  65,82898817  66,92669157  68,72218443  71,08541799  71,99493287
# 4          NaN          NaN          NaN          NaN          NaN
#
#           2019 2020
# 0          NaN  NaN
# 1  43,64066111  NaN
# 2  28,84115023  NaN
# 3  73,58988624  NaN
# 4          NaN  NaN
#
# [5 rows x 65 columns]

# %%
df_bm2=df[["Country Name", "Country Code", "Indicator Name", "2019"]]

# %%
df_bm2.head(5)
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name         2019
# 0  Access to clean fuels and technologies for coo...          NaN
# 1            Access to electricity (% of population)  43,64066111
# 2  Access to electricity, rural (% of rural popul...  28,84115023
# 3  Access to electricity, urban (% of urban popul...  73,58988624
# 4  Account ownership at a financial institution o...          NaN

# %%
df_bm3=df_bm2[df_bm2['Indicator Name']=="GDP per capita (current US$)"]

# %%
df_bm3.head(5)
# Out:
#                         Country Name Country Code  \
# 473      Africa Eastern and Southern          AFE
# 1916      Africa Western and Central          AFW
# 3359                      Arab World          ARB
# 4802          Caribbean small states          CSS
# 6245  Central Europe and the Baltics          CEB
#
#                     Indicator Name         2019
# 473   GDP per capita (current US$)  1481,425292
# 1916  GDP per capita (current US$)  1772,339155
# 3359  GDP per capita (current US$)  6570,174197
# 4802  GDP per capita (current US$)  10355,40768
# 6245  GDP per capita (current US$)    16294,377

# %% [markdown]
# ## Fusion de nos deux bases de données
# Objectif: obtenir un df contenant les données de l'OCDE ainsi que le PIB par tête pour chaque pays

# %%
df_oecd_gdp=df_pratique_final.merge(df_bm3, on='Country Code', how='left')

# %%
df_oecd_gdp
# Out:
#      Country Code           Pays                      Revenu  \
# 0             AUS      Australie                     ÃlevÃ©
# 1             AUS      Australie                     ÃlevÃ©
# 2             AUS      Australie                     ÃlevÃ©
# 3             AUS      Australie                     ÃlevÃ©
# 4             AUS      Australie                     ÃlevÃ©
# ...           ...            ...                         ...
# 3421          ZWE       Zimbabwe  Tous les groupes de revenu
# 3422          SRB         Serbie  Tous les groupes de revenu
# 3423          MNE     MontTnTgro  Tous les groupes de revenu
# 3424          XKO         Kosovo  Tous les groupes de revenu
# 3425          SSD  Soudan du Sud  Tous les groupes de revenu
#
#                    VAR   Value Country Name                Indicator Name  \
# 0          DF_HR_PRACT    1.82    Australia  GDP per capita (current US$)
# 1        RPI_VAW_PRACT   16.90    Australia  GDP per capita (current US$)
# 2         RPI_MW_PRACT  105.50    Australia  GDP per capita (current US$)
# 3         RPI_RA_PRACT   11.00    Australia  GDP per capita (current US$)
# 4     RAPFR_SAFS_PRACT   50.00    Australia  GDP per capita (current US$)
# ...                ...     ...          ...                           ...
# 3421       DF_CM_PRACT   22.90     Zimbabwe  GDP per capita (current US$)
# 3422       DF_CM_PRACT    3.50       Serbia  GDP per capita (current US$)
# 3423       DF_CM_PRACT    2.40   Montenegro  GDP per capita (current US$)
# 3424       DF_CM_PRACT    4.40          NaN                           NaN
# 3425       DF_CM_PRACT   40.10  South Sudan  GDP per capita (current US$)
#
#              2019
# 0      55057,2047
# 1      55057,2047
# 2      55057,2047
# 3      55057,2047
# 4      55057,2047
# ...           ...
# 3421  1156,154864
# 3422  7411,558649
# 3423  8910,651554
# 3424          NaN
# 3425          NaN
#
# [3426 rows x 8 columns]

# %%
df_oecd_gdp.rename(columns={'2019': 'GDP_per_capita_2019'}, inplace=True)

# %%
df_oecd_gdp
# Out:
#      Country Code           Pays                      Revenu  \
# 0             AUS      Australie                     ÃlevÃ©
# 1             AUS      Australie                     ÃlevÃ©
# 2             AUS      Australie                     ÃlevÃ©
# 3             AUS      Australie                     ÃlevÃ©
# 4             AUS      Australie                     ÃlevÃ©
# ...           ...            ...                         ...
# 3421          ZWE       Zimbabwe  Tous les groupes de revenu
# 3422          SRB         Serbie  Tous les groupes de revenu
# 3423          MNE     MontTnTgro  Tous les groupes de revenu
# 3424          XKO         Kosovo  Tous les groupes de revenu
# 3425          SSD  Soudan du Sud  Tous les groupes de revenu
#
#                    VAR   Value Country Name                Indicator Name  \
# 0          DF_HR_PRACT    1.82    Australia  GDP per capita (current US$)
# 1        RPI_VAW_PRACT   16.90    Australia  GDP per capita (current US$)
# 2         RPI_MW_PRACT  105.50    Australia  GDP per capita (current US$)
# 3         RPI_RA_PRACT   11.00    Australia  GDP per capita (current US$)
# 4     RAPFR_SAFS_PRACT   50.00    Australia  GDP per capita (current US$)
# ...                ...     ...          ...                           ...
# 3421       DF_CM_PRACT   22.90     Zimbabwe  GDP per capita (current US$)
# 3422       DF_CM_PRACT    3.50       Serbia  GDP per capita (current US$)
# 3423       DF_CM_PRACT    2.40   Montenegro  GDP per capita (current US$)
# 3424       DF_CM_PRACT    4.40          NaN                           NaN
# 3425       DF_CM_PRACT   40.10  South Sudan  GDP per capita (current US$)
#
#      GDP_per_capita_2019
# 0             55057,2047
# 1             55057,2047
# 2             55057,2047
# 3             55057,2047
# 4             55057,2047
# ...                  ...
# 3421         1156,154864
# 3422         7411,558649
# 3423         8910,651554
# 3424                 NaN
# 3425                 NaN
#
# [3426 rows x 8 columns]

# %%
df_oecd_gdp=df_oecd_gdp[["Country Code", "Country Name", "Revenu", "VAR", "Value", "GDP_per_capita_2019"]]

# %%
df_oecd_gdp
# On obtient le df voulu: les données de l'ocde avec le PIB par habitant associé à chaque personne
# Out:
#      Country Code Country Name                      Revenu               VAR  \
# 0             AUS    Australia                     ÃlevÃ©       DF_HR_PRACT
# 1             AUS    Australia                     ÃlevÃ©     RPI_VAW_PRACT
# 2             AUS    Australia                     ÃlevÃ©      RPI_MW_PRACT
# 3             AUS    Australia                     ÃlevÃ©      RPI_RA_PRACT
# 4             AUS    Australia                     ÃlevÃ©  RAPFR_SAFS_PRACT
# ...           ...          ...                         ...               ...
# 3421          ZWE     Zimbabwe  Tous les groupes de revenu       DF_CM_PRACT
# 3422          SRB       Serbia  Tous les groupes de revenu       DF_CM_PRACT
# 3423          MNE   Montenegro  Tous les groupes de revenu       DF_CM_PRACT
# 3424          XKO          NaN  Tous les groupes de revenu       DF_CM_PRACT
# 3425          SSD  South Sudan  Tous les groupes de revenu       DF_CM_PRACT
#
#        Value GDP_per_capita_2019
# 0       1.82          55057,2047
# 1      16.90          55057,2047
# 2     105.50          55057,2047
# 3      11.00          55057,2047
# 4      50.00          55057,2047
# ...      ...                 ...
# 3421   22.90         1156,154864
# 3422    3.50         7411,558649
# 3423    2.40         8910,651554
# 3424    4.40                 NaN
# 3425   40.10                 NaN
#
# [3426 rows x 6 columns]

# %% [markdown]
# # Analyse des données

# %% [markdown]
# #### Testons le lien entre les violences faites aux femmes (via la variable RPI_VAW_PRACT: Violences à l’encontre des femmes : pourcentage de femmes ayant déjà subi des violences sexuelles ou physique de la part d’un partenaire) et le PIB des pays.

# %%
df_violences=df_oecd_gdp[df_oecd_gdp['VAR']=="RPI_VAW_PRACT"]

# %%
df_violences
# Out:
#      Country Code    Country Name                      Revenu            VAR  \
# 1             AUS       Australia                     ÃlevÃ©  RPI_VAW_PRACT
# 10            AUT         Austria                     ÃlevÃ©  RPI_VAW_PRACT
# 20            BEL         Belgium                     ÃlevÃ©  RPI_VAW_PRACT
# 30            CAN          Canada                     ÃlevÃ©  RPI_VAW_PRACT
# 39            CZE  Czech Republic                     ÃlevÃ©  RPI_VAW_PRACT
# ...           ...             ...                         ...            ...
# 2999          VNM         Vietnam  Tous les groupes de revenu  RPI_VAW_PRACT
# 3008          YEM     Yemen, Rep.  Tous les groupes de revenu  RPI_VAW_PRACT
# 3017          ZMB          Zambia  Tous les groupes de revenu  RPI_VAW_PRACT
# 3028          ZWE        Zimbabwe  Tous les groupes de revenu  RPI_VAW_PRACT
# 3038          SRB          Serbia  Tous les groupes de revenu  RPI_VAW_PRACT
#
#       Value GDP_per_capita_2019
# 1      16.9          55057,2047
# 10     13.0         50121,55421
# 20     24.0         46414,43523
# 30      1.9         46326,67264
# 39     21.0         23490,39846
# ...     ...                 ...
# 2999   34.4          2715,27598
# 3008   67.0                 NaN
# 3017   42.7         1305,002214
# 3028   35.4         1156,154864
# 3038   23.7         7411,558649
#
# [270 rows x 6 columns]

# %%
index_with_nan = df_violences.index[df_violences.isnull().any(axis=1)]
index_with_nan.shape
# Out:
# (2,)

# %%
df_violences.drop(index_with_nan,0, inplace=True)
df_violences.shape
# Out:
# C:\Users\julie\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (268, 6)

# %%
Violence_on_women = df_violences.Value
GDP_per_capita = df_violences.GDP_per_capita_2019

plt.scatter(Violence_on_women, GDP_per_capita)
plt.show()

# %% [markdown]
# #### Testons le lien entre les responsabilités dans le ménage (via la variable DF_HR_PRACT: Ratio femmes/hommes du temps consacré aux tâches domestiques) et le PIB des pays.

# %%
df_domestique=df_oecd_gdp[df_oecd_gdp['VAR']=="DF_HR_PRACT"]
df_domestique
# Out:
#      Country Code Country Name                      Revenu          VAR  \
# 0             AUS    Australia                     ÃlevÃ©  DF_HR_PRACT
# 9             AUT      Austria                     ÃlevÃ©  DF_HR_PRACT
# 19            BEL      Belgium                     ÃlevÃ©  DF_HR_PRACT
# 29            CAN       Canada                     ÃlevÃ©  DF_HR_PRACT
# 48            DNK      Denmark                     ÃlevÃ©  DF_HR_PRACT
# ...           ...          ...                         ...          ...
# 2949          UGA       Uganda  Tous les groupes de revenu  DF_HR_PRACT
# 2974          URY      Uruguay  Tous les groupes de revenu  DF_HR_PRACT
# 2998          VNM      Vietnam  Tous les groupes de revenu  DF_HR_PRACT
# 3027          ZWE     Zimbabwe  Tous les groupes de revenu  DF_HR_PRACT
# 3037          SRB       Serbia  Tous les groupes de revenu  DF_HR_PRACT
#
#       Value GDP_per_capita_2019
# 0      1.82          55057,2047
# 9      1.95         50121,55421
# 19     1.55         46414,43523
# 29     1.51         46326,67264
# 48     1.39         60213,09215
# ...     ...                 ...
# 2949   3.88         794,4514454
# 2974   2.32         17688,01501
# 2998   1.48          2715,27598
# 3027   1.93         1156,154864
# 3037   2.03         7411,558649
#
# [204 rows x 6 columns]

# %%
index_with_nan = df_domestique.index[df_domestique.isnull().any(axis=1)]
index_with_nan.shape
df_domestique.drop(index_with_nan,0, inplace=True)
df_domestique.shape
# Out:
# C:\Users\julie\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (202, 6)

# %%
Repartition = df_domestique.Value
GDP_per_capita = df_domestique.GDP_per_capita_2019

plt.scatter(Repartition, GDP_per_capita)
plt.show()
