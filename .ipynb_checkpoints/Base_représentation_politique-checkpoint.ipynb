# %%
#Objectif : créer une base qui regroupe les données sur la représentation politique des femmes
#Données récupérées sur le site de l'union interparlementaire : https://data.ipu.org/fr/women-ranking?month=11&year=2021

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import urllib
import bs4
import pandas
from urllib import request
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model

# %% [markdown]
# # Création de la base de données Représentation Politique

# %% [markdown]
# ## Données sur la proportion de femmes au parlement par pays (en fonction de la chambre)

# %%
df_percent_women = pd.read_csv('C:/Users/gadole/Documents/cours/Ensae/2A/python/projet/RP/chamber--current_women_percent.csv', sep=',', encoding='utf-8')
df_percent_women.head()
# Out:
#   Source: Inter-Parliamentary Union Open Data Unnamed: 1  \
# 0                            Date: 2021-12-27        NaN
# 1             Classement au 1er Novembre 2021        NaN
# 2                                         NaN        NaN
# 3                                  Classement       Pays
# 4                                         NaN        NaN
#
#                 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5     Unnamed: 6  \
# 0                      NaN        NaN        NaN        NaN            NaN
# 1                      NaN        NaN        NaN        NaN            NaN
# 2                      NaN        NaN        NaN        NaN            NaN
# 3  Chambre basse ou unique        NaN        NaN        NaN  Chambre haute
# 4                Elections     Sièges     Femmes        % W      Elections
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4     Sièges     Femmes        % W

# %%
df_percent_women = df_percent_women.iloc[3: , : ]
df_percent_women.drop(df_percent_women.columns[[0]], axis=1, inplace=True)
df_percent_women.head()
# Out:
#   Unnamed: 1               Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3       Pays  Chambre basse ou unique        NaN        NaN        NaN
# 4        NaN                Elections     Sièges     Femmes        % W
# 5     Rwanda                  09.2018         80         49       61.3
# 6       Cuba                  03.2018        586        313       53.4
# 7  Nicaragua                  11.2016         91         46       50.6
#
#       Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 3  Chambre haute        NaN        NaN        NaN
# 4      Elections     Sièges     Femmes        % W
# 5        09.2019         26         10       38.5
# 6              -          -          -          -
# 7              -          -          -          -

# %%
df_percent_women.columns = ["Country", "Elections (lower house)", "Seats", "Women", "Women proportion (lower house)", "Elections (upper house)", "Seats", "Women", "Women proportion (upper house)"]
df_percent_women = df_percent_women.iloc[2: , : ]
df_percent_women.reset_index(inplace=True, drop=True)
df_percent_women.head()
# Out:
#                Country Elections (lower house) Seats Women  \
# 0               Rwanda                 09.2018    80    49
# 1                 Cuba                 03.2018   586   313
# 2            Nicaragua                 11.2016    91    46
# 3  Emirats arabes unis                 10.2019    40    20
# 4              Mexique                 06.2021   500   250
#
#   Women proportion (lower house) Elections (upper house) Seats Women  \
# 0                           61.3                 09.2019    26    10
# 1                           53.4                       -     -     -
# 2                           50.6                       -     -     -
# 3                             50                       -     -     -
# 4                             50                 07.2018   128    63
#
#   Women proportion (upper house)
# 0                           38.5
# 1                              -
# 2                              -
# 3                              -
# 4                           49.2

# %%
#On ne conserve que les colonnes utiles 
df_percent_women2 = df_percent_women[["Country", "Women proportion (lower house)", "Women proportion (upper house)"]]
df_percent_women2
# Out:
#                  Country Women proportion (lower house)  \
# 0                 Rwanda                           61.3
# 1                   Cuba                           53.4
# 2              Nicaragua                           50.6
# 3    Emirats arabes unis                             50
# 4                Mexique                             50
# ..                   ...                            ...
# 188              Vanuatu                              0
# 189                Yémen                              0
# 190             Erythrée                              -
# 191                Haïti                              -
# 192               Soudan                              -
#
#     Women proportion (upper house)
# 0                             38.5
# 1                                -
# 2                                -
# 3                                -
# 4                             49.2
# ..                             ...
# 188                              -
# 189                            1.1
# 190                              -
# 191                              0
# 192                              -
#
# [193 rows x 3 columns]

# %% [markdown]
# ## Données sur l'existence de quota électoraux concernant les femmes

# %%
df_quota = pd.read_csv('C:/Users/gadole/Documents/cours/Ensae/2A/python/projet/RP/chamber--field_is_electoral_quota_women.csv', sep=',', encoding='utf-8')
df_quota.head()
# Out:
#   Source : base de données Parline sur les parlements nationaux (https://data.ipu.org).  \
# 0  Droit d'auteur : Union interparlementaire. Con...
# 1      Champ sélectionné : Quota électoral de femmes
# 2                          Année de référence : 2021
# 3                            Exported on: 2021-12-27
# 4                                                NaN
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN

# %%
def nettoyage(df, d, l):
    #df est le data frame
    #d représente l'indice des colonnes à supprimer
    #l représente l'indice de lignes à partir duquel il convient de conserver les données
    df = df.drop(df.columns[d], axis=1) #On supprime les colonnes vides
    df = df.iloc[l: , : ] #On conserve les lignes comportant les noms des colonnes et les données
    df.columns = df.iloc[0] #On renomme les colonnes
    df.reset_index(inplace=True, drop=True) 
    df = df.iloc[pd.RangeIndex(len(df)).drop(0)] 
    df.reset_index(inplace=True, drop=True)
    return df

# %%
df_quota = nettoyage(df_quota, 6, 5)
df_quota.head()
# Out:
# 5 Code ISO            Pays                        Chambre  \
# 0       AF     Afghanistan              Chambre du peuple
# 1       ZA  Afrique du Sud            Assemblée nationale
# 2       AL         Albanie                      Parlement
# 3       DZ         Algérie  Assemblée populaire nationale
# 4       DE       Allemagne             Bundestag allemand
#
# 5 Quota électoral de femmes   Structure Type de chambre
# 0                       Oui   Bicameral   Chambre basse
# 1                       Oui   Bicameral   Chambre basse
# 2                       Oui  Unicameral             NaN
# 3                       Oui   Bicameral   Chambre basse
# 4                       Oui   Bicameral   Chambre basse

# %%
df_quota.columns = ["2-alpha code", "Country", "House", "Quota", "Structure", "House type"]
df_quota.head()
# Out:
#   2-alpha code         Country                          House Quota  \
# 0           AF     Afghanistan              Chambre du peuple   Oui
# 1           ZA  Afrique du Sud            Assemblée nationale   Oui
# 2           AL         Albanie                      Parlement   Oui
# 3           DZ         Algérie  Assemblée populaire nationale   Oui
# 4           DE       Allemagne             Bundestag allemand   Oui
#
#     Structure     House type
# 0   Bicameral  Chambre basse
# 1   Bicameral  Chambre basse
# 2  Unicameral            NaN
# 3   Bicameral  Chambre basse
# 4   Bicameral  Chambre basse

# %%
df_quota2 = df_quota[["2-alpha code", "Country", "Quota"]]
df_quota2
# Out:
#     2-alpha code                                 Country Quota
# 0             AF                             Afghanistan   Oui
# 1             ZA                          Afrique du Sud   Oui
# 2             AL                                 Albanie   Oui
# 3             DZ                                 Algérie   Oui
# 4             DE                               Allemagne   Oui
# ..           ...                                     ...   ...
# 185           VE  Venezuela (République bolivarienne du)   Oui
# 186           VN                                Viet Nam   Non
# 187           YE                                   Yémen   Non
# 188           ZM                                  Zambie   Non
# 189           ZW                                Zimbabwe   Non
#
# [190 rows x 3 columns]

# %% [markdown]
# ## Existence d'un organe spécialisé sur la question de l'égalité des sexes

# %%
df_spe_body = pd.read_csv('C:/Users/gadole/Documents/cours/Ensae/2A/python/projet/RP/chamber--specialized_body__women.csv', sep=',', encoding='utf-8')
df_spe_body.head()
# Out:
#   Source : base de données Parline sur les parlements nationaux (https://data.ipu.org).  \
# 0  Droit d'auteur : Union interparlementaire. Con...
# 1  Field name: Organes spécialisés - Egalité des ...
# 2                          Année de référence : 2021
# 3                            Exported on: 2021-12-27
# 4                                                NaN
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN

# %%
df_spe_body = nettoyage(df_spe_body, 6, 5)
df_spe_body.head()
# Out:
# 5 Code ISO            Pays                        Chambre  \
# 0       AF     Afghanistan              Chambre du peuple
# 1       ZA  Afrique du Sud            Assemblée nationale
# 2       AL         Albanie                      Parlement
# 3       DZ         Algérie  Assemblée populaire nationale
# 4       DE       Allemagne             Bundestag allemand
#
# 5 Organes spécialisés - Egalité des sexes   Structure Type de chambre
# 0                                     Oui   Bicameral   Chambre basse
# 1                                     Oui   Bicameral   Chambre basse
# 2                                     Oui  Unicameral             NaN
# 3                                     Non   Bicameral   Chambre basse
# 4                                     Oui   Bicameral   Chambre basse

# %%
df_spe_body.columns = ["2-alpha code", "Country", "House", "Specialized body", "Structure", "House type"]
df_spe_body.head()
# Out:
#   2-alpha code         Country                          House  \
# 0           AF     Afghanistan              Chambre du peuple
# 1           ZA  Afrique du Sud            Assemblée nationale
# 2           AL         Albanie                      Parlement
# 3           DZ         Algérie  Assemblée populaire nationale
# 4           DE       Allemagne             Bundestag allemand
#
#   Specialized body   Structure     House type
# 0              Oui   Bicameral  Chambre basse
# 1              Oui   Bicameral  Chambre basse
# 2              Oui  Unicameral            NaN
# 3              Non   Bicameral  Chambre basse
# 4              Oui   Bicameral  Chambre basse

# %%
df_spe_body2 = df_spe_body[["2-alpha code", "Specialized body"]]
df_spe_body2
# Out:
#     2-alpha code   Specialized body
# 0             AF                Oui
# 1             ZA                Oui
# 2             AL                Oui
# 3             DZ                Non
# 4             DE                Oui
# ..           ...                ...
# 187           VE  Pas d'information
# 188           VN                Oui
# 189           YE  Pas d'information
# 190           ZM                Oui
# 191           ZW                Oui
#
# [192 rows x 2 columns]

# %% [markdown]
# # Importation d'une base de données pour permettre la fusion de ces bases

# %%
# Pour permettre d'harmoniser les codes pays entre les différentes bases de données
df_country_code = pd.read_csv('C:/Users/gadole/Documents/cours/Ensae/2A/python/projet/WDICountry.csv', sep=',', encoding='utf-8')
df_country_code.head()
# Out:
#   Country Code                   Short Name                   Table Name  \
# 0          ABW                        Aruba                        Aruba
# 1          AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2          AFG                  Afghanistan                  Afghanistan
# 3          AFW   Africa Western and Central   Africa Western and Central
# 4          AGO                       Angola                       Angola
#
#                       Long Name 2-alpha code   Currency Unit  \
# 0                         Aruba           AW   Aruban florin
# 1   Africa Eastern and Southern           ZH             NaN
# 2  Islamic State of Afghanistan           AF  Afghan afghani
# 3    Africa Western and Central           ZI             NaN
# 4   People's Republic of Angola           AO  Angolan kwanza
#
#                                        Special Notes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  Fiscal year end: March 20; reporting period fo...
# 3  22 countries, stretching from the westernmost ...
# 4                                                NaN
#
#                       Region         Income Group WB-2 code  ...  \
# 0  Latin America & Caribbean          High income        AW  ...
# 1                        NaN                  NaN        ZH  ...
# 2                 South Asia           Low income        AF  ...
# 3                        NaN                  NaN        ZI  ...
# 4         Sub-Saharan Africa  Lower middle income        AO  ...
#
#      Government Accounting concept  \
# 0                              NaN
# 1                              NaN
# 2  Consolidated central government
# 3                              NaN
# 4     Budgetary central government
#
#                      IMF data dissemination standard Latest population census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 1                                                NaN                      NaN
# 2  Enhanced General Data Dissemination System (e-...                     1979
# 3                                                NaN                      NaN
# 4  Enhanced General Data Dissemination System (e-...                     2014
#
#                   Latest household survey  \
# 0                                     NaN
# 1                                     NaN
# 2     Demographic and Health Survey, 2015
# 3                                     NaN
# 4  Demographic and Health Survey, 2015/16
#
#   Source of most recent Income and expenditure data  \
# 0                                               NaN
# 1                                               NaN
# 2        Integrated household survey (IHS), 2016/17
# 3                                               NaN
# 4        Integrated household survey (IHS), 2008/09
#
#   Vital registration complete Latest agricultural census  \
# 0                         Yes                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    Latest industrial data Latest trade data Unnamed: 30
# 0                     NaN            2018.0         NaN
# 1                     NaN               NaN         NaN
# 2                     NaN            2018.0         NaN
# 3                     NaN               NaN         NaN
# 4                     NaN            2018.0         NaN
#
# [5 rows x 31 columns]

# %%
df_country_code2 = df_country_code[["Country Code", "2-alpha code"]]
df_country_code2
# Out:
#     Country Code 2-alpha code
# 0            ABW           AW
# 1            AFE           ZH
# 2            AFG           AF
# 3            AFW           ZI
# 4            AGO           AO
# ..           ...          ...
# 260          XKX           XK
# 261          YEM           YE
# 262          ZAF           ZA
# 263          ZMB           ZM
# 264          ZWE           ZW
#
# [265 rows x 2 columns]

# %% [markdown]
# # Traitement des données de la banque mondiale

# %%
df = pd.read_csv('C:/Users/gadole/Documents/cours/Ensae/2A/python/projet/WDIData.csv')
df.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2012       2013       2014  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.320475  16.643243  16.994695
# 1   NaN   NaN   NaN   NaN   NaN  ...  32.224027  32.046478  31.323579
# 2   NaN   NaN   NaN   NaN   NaN  ...  20.525353  19.461383  17.790698
# 3   NaN   NaN   NaN   NaN   NaN  ...  66.303599  66.496010  65.828988
# 4   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
#
#         2015       2016       2017       2018       2019  2020  Unnamed: 65
# 0  17.313168  17.604950        NaN        NaN        NaN   NaN          NaN
# 1  33.312163  38.380433  39.754201  42.168241  43.640661   NaN          NaN
# 2  16.553470  23.907897  24.624725  26.813900  28.841150   NaN          NaN
# 3  66.926692  68.722184  71.085418  71.994933  73.589886   NaN          NaN
# 4        NaN        NaN        NaN        NaN        NaN   NaN          NaN
#
# [5 rows x 66 columns]

# %%
df_bm2=df[["Country Code", "Indicator Name", "2019"]]
df_bm3=df_bm2[df_bm2['Indicator Name']=="GDP per capita (constant 2015 US$)"]
df_bm3.head()
# Out:
#      Country Code                      Indicator Name          2019
# 469           AFE  GDP per capita (constant 2015 US$)   1499.256275
# 1912          AFW  GDP per capita (constant 2015 US$)   1843.558468
# 3355          ARB  GDP per capita (constant 2015 US$)   6206.570758
# 4798          CSS  GDP per capita (constant 2015 US$)  10050.327615
# 6241          CEB  GDP per capita (constant 2015 US$)  14823.026908

# %% [markdown]
# # On fusionne les bases de données

# %%
df_rp_gdp = df_quota2.merge(df_country_code2, on='2-alpha code', how='left')
df_rp_gdp = df_rp_gdp.merge(df_spe_body2, on='2-alpha code', how='left')
df_rp_gdp = df_rp_gdp.merge(df_percent_women2, on='Country', how='left')
df_rp_gdp = df_rp_gdp.merge(df_bm3, on='Country Code', how='left')
df_rp_gdp = df_rp_gdp.drop(df_rp_gdp.columns[0], axis=1)
df_rp_gdp
# Out:
#                                     Country Quota Country Code  \
# 0                               Afghanistan   Oui          AFG
# 1                            Afrique du Sud   Oui          ZAF
# 2                                   Albanie   Oui          ALB
# 3                                   Algérie   Oui          DZA
# 4                                 Allemagne   Oui          DEU
# ..                                      ...   ...          ...
# 186  Venezuela (République bolivarienne du)   Oui          VEN
# 187                                Viet Nam   Non          VNM
# 188                                   Yémen   Non          YEM
# 189                                  Zambie   Non          ZMB
# 190                                Zimbabwe   Non          ZWE
#
#       Specialized body Women proportion (lower house)  \
# 0                  Oui                             27
# 1                  Oui                           46.4
# 2                  Oui                           35.7
# 3                  Non                            8.1
# 4                  Oui                           34.9
# ..                 ...                            ...
# 186  Pas d'information                           22.2
# 187                Oui                           30.3
# 188  Pas d'information                              0
# 189                Oui                           15.1
# 190                Oui                           31.9
#
#     Women proportion (upper house)                      Indicator Name  \
# 0                             27.9  GDP per capita (constant 2015 US$)
# 1                             41.5  GDP per capita (constant 2015 US$)
# 2                                -  GDP per capita (constant 2015 US$)
# 3                              5.7  GDP per capita (constant 2015 US$)
# 4                             33.3  GDP per capita (constant 2015 US$)
# ..                             ...                                 ...
# 186                              -  GDP per capita (constant 2015 US$)
# 187                              -  GDP per capita (constant 2015 US$)
# 188                            1.1  GDP per capita (constant 2015 US$)
# 189                              -  GDP per capita (constant 2015 US$)
# 190                           43.8  GDP per capita (constant 2015 US$)
#
#              2019
# 0      577.563058
# 1     5574.643890
# 2     4549.457441
# 3     4111.306192
# 4    43311.628981
# ..            ...
# 186           NaN
# 187   2604.224166
# 188           NaN
# 189   1348.743220
# 190   1367.676915
#
# [191 rows x 8 columns]

# %%
def replace_column(df, col_name, L_old_value, L_new_value) :
    for i in range(len(L_old_value)) :
        df[col_name] = df[col_name].replace(L_old_value[i], L_new_value[i])
    return df

# %%
replace_column(df_rp_gdp, "Quota", ['Oui', 'Non', "Pas d'information"], [1, 0, np.nan])
replace_column(df_rp_gdp, "Specialized body", ['Oui', 'Non', "Pas d'information"], [1, 0, np.nan])
replace_column(df_rp_gdp, "Women proportion (lower house)", ['-'], [np.nan])
replace_column(df_rp_gdp, "Women proportion (upper house)", ['-'], [np.nan])
# Out:
#                                     Country  Quota Country Code  \
# 0                               Afghanistan      1          AFG
# 1                            Afrique du Sud      1          ZAF
# 2                                   Albanie      1          ALB
# 3                                   Algérie      1          DZA
# 4                                 Allemagne      1          DEU
# ..                                      ...    ...          ...
# 186  Venezuela (République bolivarienne du)      1          VEN
# 187                                Viet Nam      0          VNM
# 188                                   Yémen      0          YEM
# 189                                  Zambie      0          ZMB
# 190                                Zimbabwe      0          ZWE
#
#      Specialized body Women proportion (lower house)  \
# 0                 1.0                             27
# 1                 1.0                           46.4
# 2                 1.0                           35.7
# 3                 0.0                            8.1
# 4                 1.0                           34.9
# ..                ...                            ...
# 186               NaN                           22.2
# 187               1.0                           30.3
# 188               NaN                              0
# 189               1.0                           15.1
# 190               1.0                           31.9
#
#     Women proportion (upper house)                      Indicator Name  \
# 0                             27.9  GDP per capita (constant 2015 US$)
# 1                             41.5  GDP per capita (constant 2015 US$)
# 2                              NaN  GDP per capita (constant 2015 US$)
# 3                              5.7  GDP per capita (constant 2015 US$)
# 4                             33.3  GDP per capita (constant 2015 US$)
# ..                             ...                                 ...
# 186                            NaN  GDP per capita (constant 2015 US$)
# 187                            NaN  GDP per capita (constant 2015 US$)
# 188                            1.1  GDP per capita (constant 2015 US$)
# 189                            NaN  GDP per capita (constant 2015 US$)
# 190                           43.8  GDP per capita (constant 2015 US$)
#
#              2019
# 0      577.563058
# 1     5574.643890
# 2     4549.457441
# 3     4111.306192
# 4    43311.628981
# ..            ...
# 186           NaN
# 187   2604.224166
# 188           NaN
# 189   1348.743220
# 190   1367.676915
#
# [191 rows x 8 columns]

# %%
df_rp_gdp.to_csv(r'C:/Users/gadole/Documents/cours/Ensae/2A/python/projet/RP/donnees_representation_pol.csv')

# %% [markdown]
# # Création de l'indicateur représentation politique

# %%
df_rp_gdp.dropna(inplace=True)

# %%
X = df_rp_gdp[["Quota", "Specialized body", "Women proportion (lower house)", "Women proportion (upper house)"]]
X = sm.add_constant(X)
y = df_rp_gdp["2019"]

model = sm.OLS(y, X.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   2019   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     2.724
# Date:                Sun, 02 Jan 2022   Prob (F-statistic):             0.0363
# Time:                        21:25:09   Log-Likelihood:                -828.42
# No. Observations:                  74   AIC:                             1667.
# Df Residuals:                      69   BIC:                             1678.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                          -1216.9879   6713.703     -0.181      0.857   -1.46e+04    1.22e+04
# Quota                           6690.2762   5480.627      1.221      0.226   -4243.275    1.76e+04
# Specialized body                -604.9874   5243.046     -0.115      0.908   -1.11e+04    9854.602
# Women proportion (lower house)    63.3952    218.878      0.290      0.773    -373.255     500.045
# Women proportion (upper house)   396.6945    199.008      1.993      0.050      -0.316     793.705
# ==============================================================================
# Omnibus:                       33.585   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.693
# Skew:                           1.629   Prob(JB):                     2.00e-15
# Kurtosis:                       6.367   Cond. No.                         149.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
